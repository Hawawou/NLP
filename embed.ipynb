# %%
import io
import re
import string
import tqdm
import pandas as pd

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    Unnamed: 0                                           Sentence
# 0           0  The Cardiff Roller Collective (CRoC) are a rol...
# 1           1  "Go! Pack Go!" is the fight song of the Green ...
# 2           2  Al-Machriq (English translation: The East) was...
# 3           3  Ajman International Airport (Arabic: مطار عجما...
# 4           4  Kapla is a construction set for children and a...

# %%
text = df['Sentence'].values
print(text[:5])
# Out:
# ['The Cardiff Roller Collective (CRoC) are a roller sports league based in Cardiff, Wales. Founded'
#  '"Go! Pack Go!" is the fight song of the Green Bay Packers, and the first'
#  'Al-Machriq (English translation: The East) was a journal founded in 1898 by Jesuit and Chaldean'
#  'Ajman International Airport (Arabic: مطار عجمان الدولي) was an upcoming airport which is currently a'
#  'Kapla is a construction set for children and adults. The sets consist only of identical']

# %%
def clean_text(sentence):
    pattern = "^[a-zA-Z0-9 ]+$"
    tokens = word_tokenize(sentence)
    tokens = [token.lower() for token in tokens if re.match(pattern, token)]

    return tokens

# %%
import collections

tokens2int = collections.defaultdict(lambda: len(tokens2int))

# %%
def tokens_2_int(text):
    token_list = clean_text(text)
    return [tokens2int[token] for token in token_list]

def text_list_2_int(text_list):
    return [tokens_2_int(text) for text in text_list]

# %%
df['Vectors'] = text_list_2_int(df['Sentence'])
df.head()
# Out:
#    Unnamed: 0                                           Sentence  \
# 0           0  The Cardiff Roller Collective (CRoC) are a rol...
# 1           1  "Go! Pack Go!" is the fight song of the Green ...
# 2           2  Al-Machriq (English translation: The East) was...
# 3           3  Ajman International Airport (Arabic: مطار عجما...
# 4           4  Kapla is a construction set for children and a...
#
#                                              Vectors
# 0   [0, 1, 2, 3, 4, 5, 6, 2, 7, 8, 9, 10, 1, 11, 12]
# 1  [13, 14, 13, 15, 0, 16, 17, 18, 0, 19, 20, 21,...
# 2  [24, 25, 0, 26, 27, 6, 28, 12, 10, 29, 30, 31,...
# 3    [33, 34, 35, 36, 27, 37, 38, 35, 39, 15, 40, 6]
# 4  [41, 15, 6, 42, 43, 44, 45, 22, 46, 0, 47, 48,...

# %%
tokens2int
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'the': 0,
#              'cardiff': 1,
#              'roller': 2,
#              'collective': 3,
#              'croc': 4,
#              'are': 5,
#              'a': 6,
#              'sports': 7,
#              'league': 8,
#              'based': 9,
#              'in': 10,
#              'wales': 11,
#              'founded': 12,
#              'go': 13,
#              'pack': 14,
#              'is': 15,
#              'fight': 16,
#              'song': 17,
#              'of': 18,
#              'green': 19,
#              'bay': 20,
#              'packers': 21,
#              'and': 22,
#              'first': 23,
#              'english': 24,
#              'translation': 25,
#              'east': 26,
#              'was': 27,
#              'journal': 28,
#              '1898': 29,
#              'by': 30,
#              'jesuit': 31,
#              'chaldean': 32,
#              'ajman': 33,
#              'international': 34,
#              'airport': 35,
#              'arabic': 36,
#              'an': 37,
#              'upcoming': 38,
#              'which': 39,
#              'currently': 40,
#              'kapla': 41,
#              'construction': 42,
#              'set': 43,
#              'for': 44,
#              'children': 45,
#              'adults': 46,
#              'sets': 47,
#              'consist': 48,
#              'only': 49,
#              'identical': 50,
#              'akmal': 51,
#              'ikramovich': 52,
#              'ikramov': 53,
#              'russia': 54,
#              'uzbek': 55,
#              'ikromovich': 56,
#              'ikromov': 57,
#              '13': 58,
#              'march': 59,
#              'alabama': 60,
#              'gang': 61,
#              'nickname': 62,
#              'group': 63,
#              'nascar': 64,
#              'drivers': 65,
#              'subsequently': 66,
#              'their': 67,
#              'lori': 68,
#              'lemaris': 69,
#              'fictional': 70,
#              'mermaid': 71,
#              'dc': 72,
#              'comics': 73,
#              'romantic': 74,
#              'interest': 75,
#              'superman': 76,
#              'pasties': 77,
#              'singular': 78,
#              'pasty': 79,
#              'or': 80,
#              'pastie': 81,
#              'patches': 82,
#              'that': 83,
#              'cover': 84,
#              'person': 85,
#              'nipples': 86,
#              'areolae': 87,
#              'typically': 88,
#              'shinto': 89,
#              'japanese': 90,
#              'romanized': 91,
#              'religion': 92,
#              'originated': 93,
#              'japan': 94,
#              'classified': 95,
#              'as': 96,
#              'akaflieg': 97,
#              'abbreviation': 98,
#              'akademische': 99,
#              'fliegergruppe': 100,
#              'groups': 101,
#              'aeronautical': 102,
#              'engineering': 103,
#              'students': 104,
#              'from': 105,
#              'individual': 106,
#              'german': 107,
#              'akshar': 108,
#              'deri': 109,
#              'major': 110,
#              'site': 111,
#              'pilgrimage': 112,
#              'swaminarayan': 113,
#              'sampradaya': 114,
#              'stephen': 115,
#              'nathaniel': 116,
#              'frick': 117,
#              'born': 118,
#              'september': 119,
#              '30': 120,
#              '1964': 121,
#              'american': 122,
#              'astronaut': 123,
#              'veteran': 124,
#              'college': 125,
#              'jordan': 126,
#              'established': 127,
#              '1983': 128,
#              'part': 129,
#              'luminus': 130,
#              'education': 131,
#              'university': 132,
#              'philippines': 133,
#              'fighting': 134,
#              'maroons': 135,
#              'official': 136,
#              'women': 137,
#              'volleyball': 138,
#              'team': 139,
#              'list': 140,
#              'famous': 141,
#              'studios': 142,
#              'theatrical': 143,
#              'cartoons': 144,
#              'featuring': 145,
#              'casper': 146,
#              'friendly': 147,
#              'ghost': 148,
#              'filmography': 149,
#              'caste': 150,
#              'systems': 151,
#              'africa': 152,
#              'form': 153,
#              'social': 154,
#              'stratification': 155,
#              'found': 156,
#              'numerous': 157,
#              'ethnic': 158,
#              'monteverde': 159,
#              'angel': 160,
#              'resurrection': 161,
#              'italian': 162,
#              'angelo': 163,
#              'di': 164,
#              'della': 165,
#              'olga': 166,
#              'krishtop': 167,
#              'russian': 168,
#              '8': 169,
#              'october': 170,
#              '1957': 171,
#              'race': 172,
#              'walker': 173,
#              'who': 174,
#              'represented': 175,
#              'aish': 176,
#              'tamid': 177,
#              'hebrew': 178,
#              'continuous': 179,
#              'fire': 180,
#              'eternal': 181,
#              'flame': 182,
#              'to': 183,
#              'merlin': 184,
#              'welsh': 185,
#              'myrddin': 186,
#              'cornish': 187,
#              'marzhin': 188,
#              'breton': 189,
#              'merzhin': 190,
#              'mythical': 191,
#              'figure': 192,
#              'prominently': 193,
#              'featured': 194,
#              'czech': 195,
#              'pronunciation': 196,
#              'smirschitz': 197,
#              'town': 198,
#              'hradec': 199,
#              'district': 200,
#              'seelowitz': 201,
#              'katterbach': 202,
#              'kaserne': 203,
#              'united': 204,
#              'states': 205,
#              'army': 206,
#              'facility': 207,
#              'germany': 208,
#              'located': 209,
#              'village': 210,
#              'ngc': 211,
#              '4314': 212,
#              'barred': 213,
#              'spiral': 214,
#              'galaxy': 215,
#              'approximately': 216,
#              '53': 217,
#              'million': 218,
#              'away': 219,
#              'northern': 220,
#              'crab': 221,
#              'nebula': 222,
#              'catalogue': 223,
#              'designations': 224,
#              'm1': 225,
#              '1952': 226,
#              'taurus': 227,
#              'supernova': 228,
#              'remnant': 229,
#              'josiah': 230,
#              'kibira': 231,
#              'jokuco': 232,
#              'constituent': 233,
#              'tumaini': 234,
#              'makumira': 235,
#              'bukoba': 236,
#              'cannonball': 237,
#              'samuel': 238,
#              'zachary': 239,
#              'guthrie': 240,
#              'superhero': 241,
#              'appearing': 242,
#              'comic': 243,
#              'books': 244,
#              'published': 245,
#              'natural': 246,
#              'burial': 247,
#              'interment': 248,
#              'body': 249,
#              'dead': 250,
#              'soil': 251,
#              'akira': 252,
#              '20': 253,
#              '1965': 254,
#              'former': 255,
#              'professional': 256,
#              'al': 257,
#              'anwa': 258,
#              'aviation': 259,
#              'charter': 260,
#              'airline': 261,
#              'out': 262,
#              'riyadh': 263,
#              'saudi': 264,
#              'arabia': 265,
#              'john': 266,
#              'mccreary': 267,
#              'fabian': 268,
#              'january': 269,
#              '28': 270,
#              '1939': 271,
#              'nasa': 272,
#              'air': 273,
#              'force': 274,
#              'swedish': 275,
#              'also': 276,
#              'municipality': 277,
#              'finland': 278,
#              'municipalities': 279,
#              'aiwowo': 280,
#              'chinese': 281,
#              'pinyin': 282,
#              'traditional': 283,
#              'dessert': 284,
#              'beijing': 285,
#              'china': 286,
#              'it': 287,
#              'said': 288,
#              'william': 289,
#              'hogarth': 290,
#              '10': 291,
#              'november': 292,
#              '1697': 293,
#              '26': 294,
#              '1764': 295,
#              'painter': 296,
#              'printmaker': 297,
#              'jazeera': 298,
#              'podcasts': 299,
#              'podcast': 300,
#              'network': 301,
#              'run': 302,
#              'media': 303,
#              'ajmn': 304,
#              'airway': 305,
#              'beacon': 306,
#              'us': 307,
#              'aerial': 308,
#              'lighthouse': 309,
#              'uk': 310,
#              'europe': 311,
#              'rotating': 312,
#              'light': 313,
#              'assembly': 314,
#              'joe': 315,
#              'petagno': 316,
#              '1': 317,
#              '1948': 318,
#              'artist': 319,
#              'known': 320,
#              'principally': 321,
#              'creating': 322,
#              'images': 323,
#              'mackenzie': 324,
#              'character': 325,
#              'marvel': 326,
#              'qureshi': 327,
#              'tennis': 328,
#              'player': 329,
#              'current': 330,
#              'pakistani': 331,
#              'number': 332,
#              'one': 333,
#              'doubles': 334,
#              'akabeko': 335,
#              'red': 336,
#              'bull': 337,
#              'legendary': 338,
#              'cow': 339,
#              'aizu': 340,
#              'region': 341,
#              'buzz': 342,
#              'aldrin': 343,
#              'edwin': 344,
#              'eugene': 345,
#              '1930': 346,
#              'donald': 347,
#              'pierce': 348,
#              'supervillain': 349,
#              'meaning': 350,
#              'masses': 351,
#              'language': 352,
#              'weekly': 353,
#              'newspaper': 354,
#              'carniny': 355,
#              'amateur': 356,
#              'youth': 357,
#              'fc': 358,
#              'football': 359,
#              'club': 360,
#              'ballymena': 361,
#              'county': 362,
#              'antrim': 363,
#              'academic': 364,
#              'city': 365,
#              'alan': 366,
#              'kurdi': 367,
#              'named': 368,
#              'after': 369,
#              'drowned': 370,
#              'syrian': 371,
#              'child': 372,
#              'kurdish': 373,
#              'origin': 374,
#              'aylan': 375,
#              'tracy': 376,
#              'caldwell': 377,
#              'dyson': 378,
#              'ellen': 379,
#              'august': 380,
#              '14': 381,
#              '1969': 382,
#              'chemist': 383,
#              'rocky': 384,
#              'mountain': 385,
#              'showdown': 386,
#              'name': 387,
#              'given': 388,
#              'state': 389,
#              'rivalry': 390,
#              'fraction': 391,
#              'fractio': 392,
#              'panis': 393,
#              'latin': 394,
#              'bread': 395,
#              'ceremonial': 396,
#              'act': 397,
#              'savonlinna': 398,
#              'finnish': 399,
#              'lit': 400,
#              'savonia': 401,
#              'nyslott': 402,
#              'castle': 403,
#              'uran': 404,
#              'butka': 405,
#              '2': 406,
#              'december': 407,
#              '1938': 408,
#              'albanian': 409,
#              'writer': 410,
#              'historian': 411,
#              'politician': 412,
#              'son': 413,
#              'spanish': 414,
#              'alicante': 415,
#              'spain': 416,
#              'on': 417,
#              'founder': 418,
#              'director': 419,
#              'urdu': 420,
#              'has': 421,
#              'been': 422,
#              'most': 423,
#              'important': 424,
#              'regular': 425,
#              'publication': 426,
#              'ahmadiyya': 427,
#              'muslim': 428,
#              'aladin': 429,
#              'interactive': 430,
#              'software': 431,
#              'sky': 432,
#              'atlas': 433,
#              'created': 434,
#              'france': 435,
#              'allowing': 436,
#              'user': 437,
#              'cloghanmore': 438,
#              'megalithic': 439,
#              'chamber': 440,
#              'tomb': 441,
#              'court': 442,
#              'cairn': 443,
#              'type': 444,
#              'mubasher': 445,
#              'ajm': 446,
#              'public': 447,
#              'affairs': 448,
#              'television': 449,
#              'launched': 450,
#              'salahuddin': 451,
#              'quader': 452,
#              'chowdhury': 453,
#              '1949': 454,
#              '22': 455,
#              '2015': 456,
#              'bangladeshi': 457,
#              'minister': 458,
#              'process': 459,
#              'whereby': 460,
#              'passengers': 461,
#              'accepted': 462,
#              'at': 463,
#              'aerodynamics': 464,
#              'uncommanded': 465,
#              'rotation': 466,
#              'aircraft': 467,
#              'undesirable': 468,
#              'carrozza': 469,
#              'referred': 470,
#              'mozzarella': 471,
#              'aeronautics': 472,
#              'downwash': 473,
#              'change': 474,
#              'direction': 475,
#              'deflected': 476,
#              'aerodynamic': 477,
#              'action': 478,
#              'aktieselskab': 479,
#              'pronounced': 480,
#              'abbr': 481,
#              'unicode': 482,
#              'literally': 483,
#              'stock': 484,
#              'company': 485,
#              'akay': 486,
#              'street': 487,
#              'artists': 488,
#              'received': 489,
#              'attention': 490,
#              'akperan': 491,
#              'orshi': 492,
#              'polytechnic': 493,
#              'yandev': 494,
#              'tertiary': 495,
#              'institution': 496,
#              'near': 497,
#              'gboko': 498,
#              'benue': 499,
#              'nigeria': 500,
#              'pupil': 501,
#              'saint': 502,
#              'petersburg': 503,
#              'juma': 504,
#              'mosque': 505,
#              'sheki': 506,
#              'azerbaijan': 507,
#              'this': 508,
#              'considered': 509,
#              'surpass': 510,
#              'wrigley': 511,
#              'antacid': 512,
#              'gum': 513,
#              'shipments': 514,
#              'retail': 515,
#              'outlets': 516,
#              'were': 517,
#              'discontinued': 518,
#              'technology': 519,
#              'governmental': 520,
#              'technical': 521,
#              'madina': 522,
#              'aita': 523,
#              'mari': 524,
#              'ship': 525,
#              'maydayterraneo': 526,
#              'maritime': 527,
#              'rescue': 528,
#              'project': 529,
#              'salvamento': 530,
#              '3': 531,
#              'june': 532,
#              '1997': 533,
#              'ugandan': 534,
#              'hurdler': 535,
#              'atmospheric': 536,
#              'theatre': 537,
#              'movie': 538,
#              'palace': 539,
#              'design': 540,
#              'popular': 541,
#              'akkamma': 542,
#              'devi': 543,
#              '1918': 544,
#              '23': 545,
#              '2012': 546,
#              'indian': 547,
#              'member': 548,
#              'educational': 549,
#              'outreach': 550,
#              'program': 551,
#              'high': 552,
#              'school': 553,
#              'them': 554,
#              'elongated': 555,
#              'man': 556,
#              'randolph': 557,
#              'ralph': 558,
#              'dibny': 559,
#              'omer': 560,
#              'vrioni': 561,
#              'greek': 562,
#              'spelling': 563,
#              'vryonis': 564,
#              'leading': 565,
#              'under': 566,
#              'western': 567,
#              'stars': 568,
#              'film': 569,
#              'directed': 570,
#              'joseph': 571,
#              'kane': 572,
#              'starring': 573,
#              'victor': 574,
#              'mancha': 575,
#              'victorious': 576,
#              'surface': 577,
#              'area': 578,
#              'interacts': 579,
#              'with': 580,
#              'working': 581,
#              'fluid': 582,
#              'gas': 583,
#              'use': 584,
#              'roman': 585,
#              'cement': 586,
#              'substance': 587,
#              'developed': 588,
#              'james': 589,
#              'parker': 590,
#              '1780s': 591,
#              'being': 592,
#              'patented': 593,
#              'stohlman': 594,
#              '15': 595,
#              '1919': 596,
#              '6': 597,
#              '1998': 598,
#              'pioneer': 599,
#              'leathercraft': 600,
#              'hamishmar': 601,
#              'guard': 602,
#              'daily': 603,
#              'mandatory': 604,
#              'palestine': 605,
#              'abrahamson': 606,
#              'may': 607,
#              '19': 608,
#              '1933': 609,
#              'retired': 610,
#              'general': 611,
#              'goldthwait': 612,
#              'cup': 613,
#              'awarded': 614,
#              'winner': 615,
#              'annual': 616,
#              'triangular': 617,
#              'regatta': 618,
#              'among': 619,
#              'association': 620,
#              'space': 621,
#              'explorers': 622,
#              'organization': 623,
#              'membership': 624,
#              'composed': 625,
#              'people': 626,
#              'jim': 627,
#              'mccrary': 628,
#              '31': 629,
#              'april': 630,
#              '29': 631,
#              'photographer': 632,
#              'effect': 633,
#              'term': 634,
#              'used': 635,
#              'political': 636,
#              'science': 637,
#              'studies': 638,
#              'hungarian': 639,
#              'nyustya': 640,
#              'sobota': 641,
#              'bombing': 642,
#              'memo': 643,
#              'unpublished': 644,
#              'memorandum': 645,
#              'made': 646,
#              'within': 647,
#              'british': 648,
#              'government': 649,
#              'security': 650,
#              'refers': 651,
#              'techniques': 652,
#              'methods': 653,
#              'attempt': 654,
#              'protect': 655,
#              'muharrir': 656,
#              'liberator': 657,
#              'editor': 658,
#              'iraqi': 659,
#              'building': 660,
#              'situated': 661,
#              'zone': 662,
#              'opal': 663,
#              'luna': 664,
#              'saturnyne': 665,
#              'news': 666,
#              'channel': 667,
#              'announced': 668,
#              'paomo': 669,
#              'specialty': 670,
#              'shaanxi': 671,
#              'cuisine': 672,
#              'typical': 673,
#              'food': 674,
#              'eaten': 675,
#              'wolfgang': 676,
#              'nordwig': 677,
#              '27': 678,
#              '1943': 679,
#              'pole': 680,
#              'vaulter': 681,
#              'he': 682,
#              'competed': 683,
#              'akwila': 684,
#              'thompson': 685,
#              'simpasa': 686,
#              '1945': 687,
#              'zambian': 688,
#              'musician': 689,
#              'somewhat': 690,
#              'enigmatic': 691,
#              'aura': 692,
#              'contraction': 693,
#              'surnames': 694,
#              'three': 695,
#              'footballers': 696,
#              'gunnar': 697,
#              'gren': 698,
#              'nordahl': 699,
#              'ala': 700,
#              'kheir': 701,
#              '1985': 702,
#              'nyala': 703,
#              'sudan': 704,
#              'sudanese': 705,
#              'lancelot': 706,
#              'richard': 707,
#              'gibbs': 708,
#              '1934': 709,
#              'west': 710,
#              'indies': 711,
#              'cricketer': 712,
#              'akonnedi': 713,
#              'shrine': 714,
#              'larteh': 715,
#              'eastern': 716,
#              'ghana': 717,
#              'whitcomb': 718,
#              'pod': 719,
#              'positioned': 720,
#              'metakaolin': 721,
#              'anhydrous': 722,
#              'calcined': 723,
#              'clay': 724,
#              'mineral': 725,
#              'kaolinite': 726,
#              'minerals': 727,
#              'rich': 728,
#              'aksel': 729,
#              'february': 730,
#              '1883': 731,
#              '9': 732,
#              'danish': 733,
#              'wood': 734,
#              'akmyrat': 735,
#              'rejepow': 736,
#              'turkmen': 737,
#              'hierarch': 738,
#              'having': 739,
#              'served': 740,
#              'saparmurat': 741,
#              'niyazov': 742,
#              'chief': 743,
#              '2257': 744,
#              'globular': 745,
#              'cluster': 746,
#              'lies': 747,
#              'outskirts': 748,
#              'large': 749,
#              'magellanic': 750,
#              'vidnava': 751,
#              'weidenau': 752,
#              'polish': 753,
#              'widnawa': 754,
#              'olomouc': 755,
#              'burj': 756,
#              'arab': 757,
#              'tower': 758,
#              'arabs': 759,
#              'luxury': 760,
#              'hotel': 761,
#              'gnarrk': 762,
#              'caveman': 763,
#              'bus': 764,
#              'shuttle': 765,
#              'airspace': 766,
#              'portion': 767,
#              'atmosphere': 768,
#              'controlled': 769,
#              'country': 770,
#              'above': 771,
#              'its': 772,
#              'territory': 773,
#              'including': 774,
#              'julius': 775,
#              'nyerere': 776,
#              'agriculture': 777,
#              'jnua': 778,
#              'proposed': 779,
#              'will': 780,
#              'be': 781,
#              'astrup': 782,
#              'rectory': 783,
#              'church': 784,
#              'listed': 785,
#              'tashtamirovich': 786,
#              'noukhayev': 787,
#              '11': 788,
#              '1954': 789,
#              'spelled': 790,
#              'nukhaev': 791,
#              'airports': 792,
#              'serbia': 793,
#              'serbian': 794,
#              'cyrillic': 795,
#              'owns': 796,
#              'hatem': 797,
#              'abdel': 798,
#              'latif': 799,
#              'egyptian': 800,
#              'transport': 801,
#              'cabinet': 802,
#              'leif': 803,
#              'elggren': 804,
#              '1950': 805,
#              'sweden': 806,
#              'lives': 807,
#              'works': 808,
#              'relocation': 809,
#              'teams': 810,
#              'occurs': 811,
#              'when': 812,
#              'owner': 813,
#              'moves': 814,
#              'generally': 815,
#              'chatin': 816,
#              'sarachi': 817,
#              'paskal': 818,
#              '5824': 819,
#              'constellation': 820,
#              'lupus': 821,
#              'almost': 822,
#              'border': 823,
#              'jesus': 824,
#              'interdenominational': 825,
#              'event': 826,
#              'christians': 827,
#              'through': 828,
#              'towns': 829,
#              'revolution': 830,
#              'tripoli': 831,
#              'libya': 832,
#              'lin': 833,
#              'dan': 834,
#              'badminton': 835,
#              'authority': 836,
#              'independent': 837,
#              'entity': 838,
#              'charged': 839,
#              'operation': 840,
#              'oversight': 841,
#              'ulrich': 842,
#              'hans': 843,
#              'walter': 844,
#              'physicist': 845,
#              'engineer': 846,
#              'packing': 847,
#              'involved': 848,
#              'canned': 849,
#              'meat': 850,
#              'industry': 851,
#              'coat': 852,
#              'arms': 853,
#              'leeds': 854,
#              'council': 855,
#              'derives': 856,
#              'seventeenth': 857,
#              'century': 858,
#              'deacon': 859,
#              'akie': 860,
#              'dagogo': 861,
#              'theodore': 862,
#              'fubara': 863,
#              'banker': 864,
#              'businessman': 865,
#              'philanthropist': 866,
#              'melvin': 867,
#              'whinfield': 868,
#              'peerless': 869,
#              'mel': 870,
#              'sheppard': 871,
#              '5': 872,
#              '4': 873,
#              '1942': 874,
#              'catherine': 875,
#              'kate': 876,
#              'private': 877,
#              'catholic': 878,
#              'liberal': 879,
#              'arts': 880,
#              'paul': 881,
#              'hubble': 882,
#              'search': 883,
#              'transition': 884,
#              'comets': 885,
#              'oh': 886,
#              'emissions': 887,
#              'asteroids': 888,
#              'vladimir': 889,
#              'aleksandrovich': 890,
#              'dzhanibekov': 891,
#              'cosmonaut': 892,
#              'french': 893,
#              'composer': 894,
#              'gabriel': 895,
#              'wrote': 896,
#              'many': 897,
#              'genres': 898,
#              'songs': 899,
#              'music': 900,
#              'orchestral': 901,
#              'spicy': 902,
#              'sauce': 903,
#              'often': 904,
#              'contains': 905,
#              'tomatoes': 906,
#              'cilantro': 907,
#              'coriander': 908,
#              'pepper': 909,
#              'onions': 910,
#              'courteen': 911,
#              'later': 912,
#              'called': 913,
#              'assada': 914,
#              'trading': 915,
#              'renacci': 916,
#              '1958': 917,
#              'accountant': 918,
#              'alwasat': 919,
#              'manama': 920,
#              'bahrain': 921,
#              'documentary': 922,
#              'festival': 923,
#              'showcasing': 924,
#              'documentaries': 925,
#              'endowed': 926,
#              'qatar': 927,
#              'world': 928,
#              'nie': 929,
#              'haisheng': 930,
#              'liberation': 931,
#              'hot': 932,
#              'sweet': 933,
#              'chili': 934,
#              'puerto': 935,
#              'rico': 936,
#              'traditionally': 937,
#              'alternative': 938,
#              'privately': 939,
#              'owned': 940,
#              'millions': 941,
#              'cairo': 942,
#              'egypt': 943,
#              'history': 944,
#              'stein': 945,
#              '2051': 946,
#              'gliese': 947,
#              'g': 948,
#              'lhs': 949,
#              'nearby': 950,
#              'binary': 951,
#              'star': 952,
#              'system': 953,
#              'containing': 954,
#              'votice': 955,
#              'wotitz': 956,
#              'central': 957,
#              'toriyama': 958,
#              '1994': 959,
#              'sugar': 960,
#              'crust': 961,
#              'chocolate': 962,
#              'confectionery': 963,
#              'method': 964,
#              'prepare': 965,
#              'liquid': 966,
#              'liqueur': 967,
#              'filled': 968,
#              'chocolates': 969,
#              'aksjeselskap': 970,
#              'norwegian': 971,
#              'usually': 972,
#              'abbreviated': 973,
#              'historically': 974,
#              'oats': 975,
#              'pinhead': 976,
#              'coarse': 977,
#              'oatmeal': 978,
#              'irish': 979,
#              'groats': 980,
#              '2452': 981,
#              'planetary': 982,
#              'southern': 983,
#              'puppis': 984,
#              'assassination': 985,
#              'upon': 986,
#              'leonid': 987,
#              'brezhnev': 988,
#              'deserter': 989,
#              'memphis': 990,
#              'route': 991,
#              'traffic': 992,
#              'control': 993,
#              'center': 994,
#              'zme': 995,
#              'radio': 996,
#              'communications': 997,
#              'suliman': 998,
#              'yari': 999,
#              ...})

# %%
int2tokens = {value: key for key, value in tokens2int.items()}
int2tokens
# Out:
# {0: 'the',
#  1: 'cardiff',
#  2: 'roller',
#  3: 'collective',
#  4: 'croc',
#  5: 'are',
#  6: 'a',
#  7: 'sports',
#  8: 'league',
#  9: 'based',
#  10: 'in',
#  11: 'wales',
#  12: 'founded',
#  13: 'go',
#  14: 'pack',
#  15: 'is',
#  16: 'fight',
#  17: 'song',
#  18: 'of',
#  19: 'green',
#  20: 'bay',
#  21: 'packers',
#  22: 'and',
#  23: 'first',
#  24: 'english',
#  25: 'translation',
#  26: 'east',
#  27: 'was',
#  28: 'journal',
#  29: '1898',
#  30: 'by',
#  31: 'jesuit',
#  32: 'chaldean',
#  33: 'ajman',
#  34: 'international',
#  35: 'airport',
#  36: 'arabic',
#  37: 'an',
#  38: 'upcoming',
#  39: 'which',
#  40: 'currently',
#  41: 'kapla',
#  42: 'construction',
#  43: 'set',
#  44: 'for',
#  45: 'children',
#  46: 'adults',
#  47: 'sets',
#  48: 'consist',
#  49: 'only',
#  50: 'identical',
#  51: 'akmal',
#  52: 'ikramovich',
#  53: 'ikramov',
#  54: 'russia',
#  55: 'uzbek',
#  56: 'ikromovich',
#  57: 'ikromov',
#  58: '13',
#  59: 'march',
#  60: 'alabama',
#  61: 'gang',
#  62: 'nickname',
#  63: 'group',
#  64: 'nascar',
#  65: 'drivers',
#  66: 'subsequently',
#  67: 'their',
#  68: 'lori',
#  69: 'lemaris',
#  70: 'fictional',
#  71: 'mermaid',
#  72: 'dc',
#  73: 'comics',
#  74: 'romantic',
#  75: 'interest',
#  76: 'superman',
#  77: 'pasties',
#  78: 'singular',
#  79: 'pasty',
#  80: 'or',
#  81: 'pastie',
#  82: 'patches',
#  83: 'that',
#  84: 'cover',
#  85: 'person',
#  86: 'nipples',
#  87: 'areolae',
#  88: 'typically',
#  89: 'shinto',
#  90: 'japanese',
#  91: 'romanized',
#  92: 'religion',
#  93: 'originated',
#  94: 'japan',
#  95: 'classified',
#  96: 'as',
#  97: 'akaflieg',
#  98: 'abbreviation',
#  99: 'akademische',
#  100: 'fliegergruppe',
#  101: 'groups',
#  102: 'aeronautical',
#  103: 'engineering',
#  104: 'students',
#  105: 'from',
#  106: 'individual',
#  107: 'german',
#  108: 'akshar',
#  109: 'deri',
#  110: 'major',
#  111: 'site',
#  112: 'pilgrimage',
#  113: 'swaminarayan',
#  114: 'sampradaya',
#  115: 'stephen',
#  116: 'nathaniel',
#  117: 'frick',
#  118: 'born',
#  119: 'september',
#  120: '30',
#  121: '1964',
#  122: 'american',
#  123: 'astronaut',
#  124: 'veteran',
#  125: 'college',
#  126: 'jordan',
#  127: 'established',
#  128: '1983',
#  129: 'part',
#  130: 'luminus',
#  131: 'education',
#  132: 'university',
#  133: 'philippines',
#  134: 'fighting',
#  135: 'maroons',
#  136: 'official',
#  137: 'women',
#  138: 'volleyball',
#  139: 'team',
#  140: 'list',
#  141: 'famous',
#  142: 'studios',
#  143: 'theatrical',
#  144: 'cartoons',
#  145: 'featuring',
#  146: 'casper',
#  147: 'friendly',
#  148: 'ghost',
#  149: 'filmography',
#  150: 'caste',
#  151: 'systems',
#  152: 'africa',
#  153: 'form',
#  154: 'social',
#  155: 'stratification',
#  156: 'found',
#  157: 'numerous',
#  158: 'ethnic',
#  159: 'monteverde',
#  160: 'angel',
#  161: 'resurrection',
#  162: 'italian',
#  163: 'angelo',
#  164: 'di',
#  165: 'della',
#  166: 'olga',
#  167: 'krishtop',
#  168: 'russian',
#  169: '8',
#  170: 'october',
#  171: '1957',
#  172: 'race',
#  173: 'walker',
#  174: 'who',
#  175: 'represented',
#  176: 'aish',
#  177: 'tamid',
#  178: 'hebrew',
#  179: 'continuous',
#  180: 'fire',
#  181: 'eternal',
#  182: 'flame',
#  183: 'to',
#  184: 'merlin',
#  185: 'welsh',
#  186: 'myrddin',
#  187: 'cornish',
#  188: 'marzhin',
#  189: 'breton',
#  190: 'merzhin',
#  191: 'mythical',
#  192: 'figure',
#  193: 'prominently',
#  194: 'featured',
#  195: 'czech',
#  196: 'pronunciation',
#  197: 'smirschitz',
#  198: 'town',
#  199: 'hradec',
#  200: 'district',
#  201: 'seelowitz',
#  202: 'katterbach',
#  203: 'kaserne',
#  204: 'united',
#  205: 'states',
#  206: 'army',
#  207: 'facility',
#  208: 'germany',
#  209: 'located',
#  210: 'village',
#  211: 'ngc',
#  212: '4314',
#  213: 'barred',
#  214: 'spiral',
#  215: 'galaxy',
#  216: 'approximately',
#  217: '53',
#  218: 'million',
#  219: 'away',
#  220: 'northern',
#  221: 'crab',
#  222: 'nebula',
#  223: 'catalogue',
#  224: 'designations',
#  225: 'm1',
#  226: '1952',
#  227: 'taurus',
#  228: 'supernova',
#  229: 'remnant',
#  230: 'josiah',
#  231: 'kibira',
#  232: 'jokuco',
#  233: 'constituent',
#  234: 'tumaini',
#  235: 'makumira',
#  236: 'bukoba',
#  237: 'cannonball',
#  238: 'samuel',
#  239: 'zachary',
#  240: 'guthrie',
#  241: 'superhero',
#  242: 'appearing',
#  243: 'comic',
#  244: 'books',
#  245: 'published',
#  246: 'natural',
#  247: 'burial',
#  248: 'interment',
#  249: 'body',
#  250: 'dead',
#  251: 'soil',
#  252: 'akira',
#  253: '20',
#  254: '1965',
#  255: 'former',
#  256: 'professional',
#  257: 'al',
#  258: 'anwa',
#  259: 'aviation',
#  260: 'charter',
#  261: 'airline',
#  262: 'out',
#  263: 'riyadh',
#  264: 'saudi',
#  265: 'arabia',
#  266: 'john',
#  267: 'mccreary',
#  268: 'fabian',
#  269: 'january',
#  270: '28',
#  271: '1939',
#  272: 'nasa',
#  273: 'air',
#  274: 'force',
#  275: 'swedish',
#  276: 'also',
#  277: 'municipality',
#  278: 'finland',
#  279: 'municipalities',
#  280: 'aiwowo',
#  281: 'chinese',
#  282: 'pinyin',
#  283: 'traditional',
#  284: 'dessert',
#  285: 'beijing',
#  286: 'china',
#  287: 'it',
#  288: 'said',
#  289: 'william',
#  290: 'hogarth',
#  291: '10',
#  292: 'november',
#  293: '1697',
#  294: '26',
#  295: '1764',
#  296: 'painter',
#  297: 'printmaker',
#  298: 'jazeera',
#  299: 'podcasts',
#  300: 'podcast',
#  301: 'network',
#  302: 'run',
#  303: 'media',
#  304: 'ajmn',
#  305: 'airway',
#  306: 'beacon',
#  307: 'us',
#  308: 'aerial',
#  309: 'lighthouse',
#  310: 'uk',
#  311: 'europe',
#  312: 'rotating',
#  313: 'light',
#  314: 'assembly',
#  315: 'joe',
#  316: 'petagno',
#  317: '1',
#  318: '1948',
#  319: 'artist',
#  320: 'known',
#  321: 'principally',
#  322: 'creating',
#  323: 'images',
#  324: 'mackenzie',
#  325: 'character',
#  326: 'marvel',
#  327: 'qureshi',
#  328: 'tennis',
#  329: 'player',
#  330: 'current',
#  331: 'pakistani',
#  332: 'number',
#  333: 'one',
#  334: 'doubles',
#  335: 'akabeko',
#  336: 'red',
#  337: 'bull',
#  338: 'legendary',
#  339: 'cow',
#  340: 'aizu',
#  341: 'region',
#  342: 'buzz',
#  343: 'aldrin',
#  344: 'edwin',
#  345: 'eugene',
#  346: '1930',
#  347: 'donald',
#  348: 'pierce',
#  349: 'supervillain',
#  350: 'meaning',
#  351: 'masses',
#  352: 'language',
#  353: 'weekly',
#  354: 'newspaper',
#  355: 'carniny',
#  356: 'amateur',
#  357: 'youth',
#  358: 'fc',
#  359: 'football',
#  360: 'club',
#  361: 'ballymena',
#  362: 'county',
#  363: 'antrim',
#  364: 'academic',
#  365: 'city',
#  366: 'alan',
#  367: 'kurdi',
#  368: 'named',
#  369: 'after',
#  370: 'drowned',
#  371: 'syrian',
#  372: 'child',
#  373: 'kurdish',
#  374: 'origin',
#  375: 'aylan',
#  376: 'tracy',
#  377: 'caldwell',
#  378: 'dyson',
#  379: 'ellen',
#  380: 'august',
#  381: '14',
#  382: '1969',
#  383: 'chemist',
#  384: 'rocky',
#  385: 'mountain',
#  386: 'showdown',
#  387: 'name',
#  388: 'given',
#  389: 'state',
#  390: 'rivalry',
#  391: 'fraction',
#  392: 'fractio',
#  393: 'panis',
#  394: 'latin',
#  395: 'bread',
#  396: 'ceremonial',
#  397: 'act',
#  398: 'savonlinna',
#  399: 'finnish',
#  400: 'lit',
#  401: 'savonia',
#  402: 'nyslott',
#  403: 'castle',
#  404: 'uran',
#  405: 'butka',
#  406: '2',
#  407: 'december',
#  408: '1938',
#  409: 'albanian',
#  410: 'writer',
#  411: 'historian',
#  412: 'politician',
#  413: 'son',
#  414: 'spanish',
#  415: 'alicante',
#  416: 'spain',
#  417: 'on',
#  418: 'founder',
#  419: 'director',
#  420: 'urdu',
#  421: 'has',
#  422: 'been',
#  423: 'most',
#  424: 'important',
#  425: 'regular',
#  426: 'publication',
#  427: 'ahmadiyya',
#  428: 'muslim',
#  429: 'aladin',
#  430: 'interactive',
#  431: 'software',
#  432: 'sky',
#  433: 'atlas',
#  434: 'created',
#  435: 'france',
#  436: 'allowing',
#  437: 'user',
#  438: 'cloghanmore',
#  439: 'megalithic',
#  440: 'chamber',
#  441: 'tomb',
#  442: 'court',
#  443: 'cairn',
#  444: 'type',
#  445: 'mubasher',
#  446: 'ajm',
#  447: 'public',
#  448: 'affairs',
#  449: 'television',
#  450: 'launched',
#  451: 'salahuddin',
#  452: 'quader',
#  453: 'chowdhury',
#  454: '1949',
#  455: '22',
#  456: '2015',
#  457: 'bangladeshi',
#  458: 'minister',
#  459: 'process',
#  460: 'whereby',
#  461: 'passengers',
#  462: 'accepted',
#  463: 'at',
#  464: 'aerodynamics',
#  465: 'uncommanded',
#  466: 'rotation',
#  467: 'aircraft',
#  468: 'undesirable',
#  469: 'carrozza',
#  470: 'referred',
#  471: 'mozzarella',
#  472: 'aeronautics',
#  473: 'downwash',
#  474: 'change',
#  475: 'direction',
#  476: 'deflected',
#  477: 'aerodynamic',
#  478: 'action',
#  479: 'aktieselskab',
#  480: 'pronounced',
#  481: 'abbr',
#  482: 'unicode',
#  483: 'literally',
#  484: 'stock',
#  485: 'company',
#  486: 'akay',
#  487: 'street',
#  488: 'artists',
#  489: 'received',
#  490: 'attention',
#  491: 'akperan',
#  492: 'orshi',
#  493: 'polytechnic',
#  494: 'yandev',
#  495: 'tertiary',
#  496: 'institution',
#  497: 'near',
#  498: 'gboko',
#  499: 'benue',
#  500: 'nigeria',
#  501: 'pupil',
#  502: 'saint',
#  503: 'petersburg',
#  504: 'juma',
#  505: 'mosque',
#  506: 'sheki',
#  507: 'azerbaijan',
#  508: 'this',
#  509: 'considered',
#  510: 'surpass',
#  511: 'wrigley',
#  512: 'antacid',
#  513: 'gum',
#  514: 'shipments',
#  515: 'retail',
#  516: 'outlets',
#  517: 'were',
#  518: 'discontinued',
#  519: 'technology',
#  520: 'governmental',
#  521: 'technical',
#  522: 'madina',
#  523: 'aita',
#  524: 'mari',
#  525: 'ship',
#  526: 'maydayterraneo',
#  527: 'maritime',
#  528: 'rescue',
#  529: 'project',
#  530: 'salvamento',
#  531: '3',
#  532: 'june',
#  533: '1997',
#  534: 'ugandan',
#  535: 'hurdler',
#  536: 'atmospheric',
#  537: 'theatre',
#  538: 'movie',
#  539: 'palace',
#  540: 'design',
#  541: 'popular',
#  542: 'akkamma',
#  543: 'devi',
#  544: '1918',
#  545: '23',
#  546: '2012',
#  547: 'indian',
#  548: 'member',
#  549: 'educational',
#  550: 'outreach',
#  551: 'program',
#  552: 'high',
#  553: 'school',
#  554: 'them',
#  555: 'elongated',
#  556: 'man',
#  557: 'randolph',
#  558: 'ralph',
#  559: 'dibny',
#  560: 'omer',
#  561: 'vrioni',
#  562: 'greek',
#  563: 'spelling',
#  564: 'vryonis',
#  565: 'leading',
#  566: 'under',
#  567: 'western',
#  568: 'stars',
#  569: 'film',
#  570: 'directed',
#  571: 'joseph',
#  572: 'kane',
#  573: 'starring',
#  574: 'victor',
#  575: 'mancha',
#  576: 'victorious',
#  577: 'surface',
#  578: 'area',
#  579: 'interacts',
#  580: 'with',
#  581: 'working',
#  582: 'fluid',
#  583: 'gas',
#  584: 'use',
#  585: 'roman',
#  586: 'cement',
#  587: 'substance',
#  588: 'developed',
#  589: 'james',
#  590: 'parker',
#  591: '1780s',
#  592: 'being',
#  593: 'patented',
#  594: 'stohlman',
#  595: '15',
#  596: '1919',
#  597: '6',
#  598: '1998',
#  599: 'pioneer',
#  600: 'leathercraft',
#  601: 'hamishmar',
#  602: 'guard',
#  603: 'daily',
#  604: 'mandatory',
#  605: 'palestine',
#  606: 'abrahamson',
#  607: 'may',
#  608: '19',
#  609: '1933',
#  610: 'retired',
#  611: 'general',
#  612: 'goldthwait',
#  613: 'cup',
#  614: 'awarded',
#  615: 'winner',
#  616: 'annual',
#  617: 'triangular',
#  618: 'regatta',
#  619: 'among',
#  620: 'association',
#  621: 'space',
#  622: 'explorers',
#  623: 'organization',
#  624: 'membership',
#  625: 'composed',
#  626: 'people',
#  627: 'jim',
#  628: 'mccrary',
#  629: '31',
#  630: 'april',
#  631: '29',
#  632: 'photographer',
#  633: 'effect',
#  634: 'term',
#  635: 'used',
#  636: 'political',
#  637: 'science',
#  638: 'studies',
#  639: 'hungarian',
#  640: 'nyustya',
#  641: 'sobota',
#  642: 'bombing',
#  643: 'memo',
#  644: 'unpublished',
#  645: 'memorandum',
#  646: 'made',
#  647: 'within',
#  648: 'british',
#  649: 'government',
#  650: 'security',
#  651: 'refers',
#  652: 'techniques',
#  653: 'methods',
#  654: 'attempt',
#  655: 'protect',
#  656: 'muharrir',
#  657: 'liberator',
#  658: 'editor',
#  659: 'iraqi',
#  660: 'building',
#  661: 'situated',
#  662: 'zone',
#  663: 'opal',
#  664: 'luna',
#  665: 'saturnyne',
#  666: 'news',
#  667: 'channel',
#  668: 'announced',
#  669: 'paomo',
#  670: 'specialty',
#  671: 'shaanxi',
#  672: 'cuisine',
#  673: 'typical',
#  674: 'food',
#  675: 'eaten',
#  676: 'wolfgang',
#  677: 'nordwig',
#  678: '27',
#  679: '1943',
#  680: 'pole',
#  681: 'vaulter',
#  682: 'he',
#  683: 'competed',
#  684: 'akwila',
#  685: 'thompson',
#  686: 'simpasa',
#  687: '1945',
#  688: 'zambian',
#  689: 'musician',
#  690: 'somewhat',
#  691: 'enigmatic',
#  692: 'aura',
#  693: 'contraction',
#  694: 'surnames',
#  695: 'three',
#  696: 'footballers',
#  697: 'gunnar',
#  698: 'gren',
#  699: 'nordahl',
#  700: 'ala',
#  701: 'kheir',
#  702: '1985',
#  703: 'nyala',
#  704: 'sudan',
#  705: 'sudanese',
#  706: 'lancelot',
#  707: 'richard',
#  708: 'gibbs',
#  709: '1934',
#  710: 'west',
#  711: 'indies',
#  712: 'cricketer',
#  713: 'akonnedi',
#  714: 'shrine',
#  715: 'larteh',
#  716: 'eastern',
#  717: 'ghana',
#  718: 'whitcomb',
#  719: 'pod',
#  720: 'positioned',
#  721: 'metakaolin',
#  722: 'anhydrous',
#  723: 'calcined',
#  724: 'clay',
#  725: 'mineral',
#  726: 'kaolinite',
#  727: 'minerals',
#  728: 'rich',
#  729: 'aksel',
#  730: 'february',
#  731: '1883',
#  732: '9',
#  733: 'danish',
#  734: 'wood',
#  735: 'akmyrat',
#  736: 'rejepow',
#  737: 'turkmen',
#  738: 'hierarch',
#  739: 'having',
#  740: 'served',
#  741: 'saparmurat',
#  742: 'niyazov',
#  743: 'chief',
#  744: '2257',
#  745: 'globular',
#  746: 'cluster',
#  747: 'lies',
#  748: 'outskirts',
#  749: 'large',
#  750: 'magellanic',
#  751: 'vidnava',
#  752: 'weidenau',
#  753: 'polish',
#  754: 'widnawa',
#  755: 'olomouc',
#  756: 'burj',
#  757: 'arab',
#  758: 'tower',
#  759: 'arabs',
#  760: 'luxury',
#  761: 'hotel',
#  762: 'gnarrk',
#  763: 'caveman',
#  764: 'bus',
#  765: 'shuttle',
#  766: 'airspace',
#  767: 'portion',
#  768: 'atmosphere',
#  769: 'controlled',
#  770: 'country',
#  771: 'above',
#  772: 'its',
#  773: 'territory',
#  774: 'including',
#  775: 'julius',
#  776: 'nyerere',
#  777: 'agriculture',
#  778: 'jnua',
#  779: 'proposed',
#  780: 'will',
#  781: 'be',
#  782: 'astrup',
#  783: 'rectory',
#  784: 'church',
#  785: 'listed',
#  786: 'tashtamirovich',
#  787: 'noukhayev',
#  788: '11',
#  789: '1954',
#  790: 'spelled',
#  791: 'nukhaev',
#  792: 'airports',
#  793: 'serbia',
#  794: 'serbian',
#  795: 'cyrillic',
#  796: 'owns',
#  797: 'hatem',
#  798: 'abdel',
#  799: 'latif',
#  800: 'egyptian',
#  801: 'transport',
#  802: 'cabinet',
#  803: 'leif',
#  804: 'elggren',
#  805: '1950',
#  806: 'sweden',
#  807: 'lives',
#  808: 'works',
#  809: 'relocation',
#  810: 'teams',
#  811: 'occurs',
#  812: 'when',
#  813: 'owner',
#  814: 'moves',
#  815: 'generally',
#  816: 'chatin',
#  817: 'sarachi',
#  818: 'paskal',
#  819: '5824',
#  820: 'constellation',
#  821: 'lupus',
#  822: 'almost',
#  823: 'border',
#  824: 'jesus',
#  825: 'interdenominational',
#  826: 'event',
#  827: 'christians',
#  828: 'through',
#  829: 'towns',
#  830: 'revolution',
#  831: 'tripoli',
#  832: 'libya',
#  833: 'lin',
#  834: 'dan',
#  835: 'badminton',
#  836: 'authority',
#  837: 'independent',
#  838: 'entity',
#  839: 'charged',
#  840: 'operation',
#  841: 'oversight',
#  842: 'ulrich',
#  843: 'hans',
#  844: 'walter',
#  845: 'physicist',
#  846: 'engineer',
#  847: 'packing',
#  848: 'involved',
#  849: 'canned',
#  850: 'meat',
#  851: 'industry',
#  852: 'coat',
#  853: 'arms',
#  854: 'leeds',
#  855: 'council',
#  856: 'derives',
#  857: 'seventeenth',
#  858: 'century',
#  859: 'deacon',
#  860: 'akie',
#  861: 'dagogo',
#  862: 'theodore',
#  863: 'fubara',
#  864: 'banker',
#  865: 'businessman',
#  866: 'philanthropist',
#  867: 'melvin',
#  868: 'whinfield',
#  869: 'peerless',
#  870: 'mel',
#  871: 'sheppard',
#  872: '5',
#  873: '4',
#  874: '1942',
#  875: 'catherine',
#  876: 'kate',
#  877: 'private',
#  878: 'catholic',
#  879: 'liberal',
#  880: 'arts',
#  881: 'paul',
#  882: 'hubble',
#  883: 'search',
#  884: 'transition',
#  885: 'comets',
#  886: 'oh',
#  887: 'emissions',
#  888: 'asteroids',
#  889: 'vladimir',
#  890: 'aleksandrovich',
#  891: 'dzhanibekov',
#  892: 'cosmonaut',
#  893: 'french',
#  894: 'composer',
#  895: 'gabriel',
#  896: 'wrote',
#  897: 'many',
#  898: 'genres',
#  899: 'songs',
#  900: 'music',
#  901: 'orchestral',
#  902: 'spicy',
#  903: 'sauce',
#  904: 'often',
#  905: 'contains',
#  906: 'tomatoes',
#  907: 'cilantro',
#  908: 'coriander',
#  909: 'pepper',
#  910: 'onions',
#  911: 'courteen',
#  912: 'later',
#  913: 'called',
#  914: 'assada',
#  915: 'trading',
#  916: 'renacci',
#  917: '1958',
#  918: 'accountant',
#  919: 'alwasat',
#  920: 'manama',
#  921: 'bahrain',
#  922: 'documentary',
#  923: 'festival',
#  924: 'showcasing',
#  925: 'documentaries',
#  926: 'endowed',
#  927: 'qatar',
#  928: 'world',
#  929: 'nie',
#  930: 'haisheng',
#  931: 'liberation',
#  932: 'hot',
#  933: 'sweet',
#  934: 'chili',
#  935: 'puerto',
#  936: 'rico',
#  937: 'traditionally',
#  938: 'alternative',
#  939: 'privately',
#  940: 'owned',
#  941: 'millions',
#  942: 'cairo',
#  943: 'egypt',
#  944: 'history',
#  945: 'stein',
#  946: '2051',
#  947: 'gliese',
#  948: 'g',
#  949: 'lhs',
#  950: 'nearby',
#  951: 'binary',
#  952: 'star',
#  953: 'system',
#  954: 'containing',
#  955: 'votice',
#  956: 'wotitz',
#  957: 'central',
#  958: 'toriyama',
#  959: '1994',
#  960: 'sugar',
#  961: 'crust',
#  962: 'chocolate',
#  963: 'confectionery',
#  964: 'method',
#  965: 'prepare',
#  966: 'liquid',
#  967: 'liqueur',
#  968: 'filled',
#  969: 'chocolates',
#  970: 'aksjeselskap',
#  971: 'norwegian',
#  972: 'usually',
#  973: 'abbreviated',
#  974: 'historically',
#  975: 'oats',
#  976: 'pinhead',
#  977: 'coarse',
#  978: 'oatmeal',
#  979: 'irish',
#  980: 'groats',
#  981: '2452',
#  982: 'planetary',
#  983: 'southern',
#  984: 'puppis',
#  985: 'assassination',
#  986: 'upon',
#  987: 'leonid',
#  988: 'brezhnev',
#  989: 'deserter',
#  990: 'memphis',
#  991: 'route',
#  992: 'traffic',
#  993: 'control',
#  994: 'center',
#  995: 'zme',
#  996: 'radio',
#  997: 'communications',
#  998: 'suliman',
#  999: 'yari',
#  ...}

# %%
import string

# %%
vocabulary = list(tokens2int.keys())
vocabulary
# Out:
# ['the',
#  'cardiff',
#  'roller',
#  'collective',
#  'croc',
#  'are',
#  'a',
#  'sports',
#  'league',
#  'based',
#  'in',
#  'wales',
#  'founded',
#  'go',
#  'pack',
#  'is',
#  'fight',
#  'song',
#  'of',
#  'green',
#  'bay',
#  'packers',
#  'and',
#  'first',
#  'english',
#  'translation',
#  'east',
#  'was',
#  'journal',
#  '1898',
#  'by',
#  'jesuit',
#  'chaldean',
#  'ajman',
#  'international',
#  'airport',
#  'arabic',
#  'an',
#  'upcoming',
#  'which',
#  'currently',
#  'kapla',
#  'construction',
#  'set',
#  'for',
#  'children',
#  'adults',
#  'sets',
#  'consist',
#  'only',
#  'identical',
#  'akmal',
#  'ikramovich',
#  'ikramov',
#  'russia',
#  'uzbek',
#  'ikromovich',
#  'ikromov',
#  '13',
#  'march',
#  'alabama',
#  'gang',
#  'nickname',
#  'group',
#  'nascar',
#  'drivers',
#  'subsequently',
#  'their',
#  'lori',
#  'lemaris',
#  'fictional',
#  'mermaid',
#  'dc',
#  'comics',
#  'romantic',
#  'interest',
#  'superman',
#  'pasties',
#  'singular',
#  'pasty',
#  'or',
#  'pastie',
#  'patches',
#  'that',
#  'cover',
#  'person',
#  'nipples',
#  'areolae',
#  'typically',
#  'shinto',
#  'japanese',
#  'romanized',
#  'religion',
#  'originated',
#  'japan',
#  'classified',
#  'as',
#  'akaflieg',
#  'abbreviation',
#  'akademische',
#  'fliegergruppe',
#  'groups',
#  'aeronautical',
#  'engineering',
#  'students',
#  'from',
#  'individual',
#  'german',
#  'akshar',
#  'deri',
#  'major',
#  'site',
#  'pilgrimage',
#  'swaminarayan',
#  'sampradaya',
#  'stephen',
#  'nathaniel',
#  'frick',
#  'born',
#  'september',
#  '30',
#  '1964',
#  'american',
#  'astronaut',
#  'veteran',
#  'college',
#  'jordan',
#  'established',
#  '1983',
#  'part',
#  'luminus',
#  'education',
#  'university',
#  'philippines',
#  'fighting',
#  'maroons',
#  'official',
#  'women',
#  'volleyball',
#  'team',
#  'list',
#  'famous',
#  'studios',
#  'theatrical',
#  'cartoons',
#  'featuring',
#  'casper',
#  'friendly',
#  'ghost',
#  'filmography',
#  'caste',
#  'systems',
#  'africa',
#  'form',
#  'social',
#  'stratification',
#  'found',
#  'numerous',
#  'ethnic',
#  'monteverde',
#  'angel',
#  'resurrection',
#  'italian',
#  'angelo',
#  'di',
#  'della',
#  'olga',
#  'krishtop',
#  'russian',
#  '8',
#  'october',
#  '1957',
#  'race',
#  'walker',
#  'who',
#  'represented',
#  'aish',
#  'tamid',
#  'hebrew',
#  'continuous',
#  'fire',
#  'eternal',
#  'flame',
#  'to',
#  'merlin',
#  'welsh',
#  'myrddin',
#  'cornish',
#  'marzhin',
#  'breton',
#  'merzhin',
#  'mythical',
#  'figure',
#  'prominently',
#  'featured',
#  'czech',
#  'pronunciation',
#  'smirschitz',
#  'town',
#  'hradec',
#  'district',
#  'seelowitz',
#  'katterbach',
#  'kaserne',
#  'united',
#  'states',
#  'army',
#  'facility',
#  'germany',
#  'located',
#  'village',
#  'ngc',
#  '4314',
#  'barred',
#  'spiral',
#  'galaxy',
#  'approximately',
#  '53',
#  'million',
#  'away',
#  'northern',
#  'crab',
#  'nebula',
#  'catalogue',
#  'designations',
#  'm1',
#  '1952',
#  'taurus',
#  'supernova',
#  'remnant',
#  'josiah',
#  'kibira',
#  'jokuco',
#  'constituent',
#  'tumaini',
#  'makumira',
#  'bukoba',
#  'cannonball',
#  'samuel',
#  'zachary',
#  'guthrie',
#  'superhero',
#  'appearing',
#  'comic',
#  'books',
#  'published',
#  'natural',
#  'burial',
#  'interment',
#  'body',
#  'dead',
#  'soil',
#  'akira',
#  '20',
#  '1965',
#  'former',
#  'professional',
#  'al',
#  'anwa',
#  'aviation',
#  'charter',
#  'airline',
#  'out',
#  'riyadh',
#  'saudi',
#  'arabia',
#  'john',
#  'mccreary',
#  'fabian',
#  'january',
#  '28',
#  '1939',
#  'nasa',
#  'air',
#  'force',
#  'swedish',
#  'also',
#  'municipality',
#  'finland',
#  'municipalities',
#  'aiwowo',
#  'chinese',
#  'pinyin',
#  'traditional',
#  'dessert',
#  'beijing',
#  'china',
#  'it',
#  'said',
#  'william',
#  'hogarth',
#  '10',
#  'november',
#  '1697',
#  '26',
#  '1764',
#  'painter',
#  'printmaker',
#  'jazeera',
#  'podcasts',
#  'podcast',
#  'network',
#  'run',
#  'media',
#  'ajmn',
#  'airway',
#  'beacon',
#  'us',
#  'aerial',
#  'lighthouse',
#  'uk',
#  'europe',
#  'rotating',
#  'light',
#  'assembly',
#  'joe',
#  'petagno',
#  '1',
#  '1948',
#  'artist',
#  'known',
#  'principally',
#  'creating',
#  'images',
#  'mackenzie',
#  'character',
#  'marvel',
#  'qureshi',
#  'tennis',
#  'player',
#  'current',
#  'pakistani',
#  'number',
#  'one',
#  'doubles',
#  'akabeko',
#  'red',
#  'bull',
#  'legendary',
#  'cow',
#  'aizu',
#  'region',
#  'buzz',
#  'aldrin',
#  'edwin',
#  'eugene',
#  '1930',
#  'donald',
#  'pierce',
#  'supervillain',
#  'meaning',
#  'masses',
#  'language',
#  'weekly',
#  'newspaper',
#  'carniny',
#  'amateur',
#  'youth',
#  'fc',
#  'football',
#  'club',
#  'ballymena',
#  'county',
#  'antrim',
#  'academic',
#  'city',
#  'alan',
#  'kurdi',
#  'named',
#  'after',
#  'drowned',
#  'syrian',
#  'child',
#  'kurdish',
#  'origin',
#  'aylan',
#  'tracy',
#  'caldwell',
#  'dyson',
#  'ellen',
#  'august',
#  '14',
#  '1969',
#  'chemist',
#  'rocky',
#  'mountain',
#  'showdown',
#  'name',
#  'given',
#  'state',
#  'rivalry',
#  'fraction',
#  'fractio',
#  'panis',
#  'latin',
#  'bread',
#  'ceremonial',
#  'act',
#  'savonlinna',
#  'finnish',
#  'lit',
#  'savonia',
#  'nyslott',
#  'castle',
#  'uran',
#  'butka',
#  '2',
#  'december',
#  '1938',
#  'albanian',
#  'writer',
#  'historian',
#  'politician',
#  'son',
#  'spanish',
#  'alicante',
#  'spain',
#  'on',
#  'founder',
#  'director',
#  'urdu',
#  'has',
#  'been',
#  'most',
#  'important',
#  'regular',
#  'publication',
#  'ahmadiyya',
#  'muslim',
#  'aladin',
#  'interactive',
#  'software',
#  'sky',
#  'atlas',
#  'created',
#  'france',
#  'allowing',
#  'user',
#  'cloghanmore',
#  'megalithic',
#  'chamber',
#  'tomb',
#  'court',
#  'cairn',
#  'type',
#  'mubasher',
#  'ajm',
#  'public',
#  'affairs',
#  'television',
#  'launched',
#  'salahuddin',
#  'quader',
#  'chowdhury',
#  '1949',
#  '22',
#  '2015',
#  'bangladeshi',
#  'minister',
#  'process',
#  'whereby',
#  'passengers',
#  'accepted',
#  'at',
#  'aerodynamics',
#  'uncommanded',
#  'rotation',
#  'aircraft',
#  'undesirable',
#  'carrozza',
#  'referred',
#  'mozzarella',
#  'aeronautics',
#  'downwash',
#  'change',
#  'direction',
#  'deflected',
#  'aerodynamic',
#  'action',
#  'aktieselskab',
#  'pronounced',
#  'abbr',
#  'unicode',
#  'literally',
#  'stock',
#  'company',
#  'akay',
#  'street',
#  'artists',
#  'received',
#  'attention',
#  'akperan',
#  'orshi',
#  'polytechnic',
#  'yandev',
#  'tertiary',
#  'institution',
#  'near',
#  'gboko',
#  'benue',
#  'nigeria',
#  'pupil',
#  'saint',
#  'petersburg',
#  'juma',
#  'mosque',
#  'sheki',
#  'azerbaijan',
#  'this',
#  'considered',
#  'surpass',
#  'wrigley',
#  'antacid',
#  'gum',
#  'shipments',
#  'retail',
#  'outlets',
#  'were',
#  'discontinued',
#  'technology',
#  'governmental',
#  'technical',
#  'madina',
#  'aita',
#  'mari',
#  'ship',
#  'maydayterraneo',
#  'maritime',
#  'rescue',
#  'project',
#  'salvamento',
#  '3',
#  'june',
#  '1997',
#  'ugandan',
#  'hurdler',
#  'atmospheric',
#  'theatre',
#  'movie',
#  'palace',
#  'design',
#  'popular',
#  'akkamma',
#  'devi',
#  '1918',
#  '23',
#  '2012',
#  'indian',
#  'member',
#  'educational',
#  'outreach',
#  'program',
#  'high',
#  'school',
#  'them',
#  'elongated',
#  'man',
#  'randolph',
#  'ralph',
#  'dibny',
#  'omer',
#  'vrioni',
#  'greek',
#  'spelling',
#  'vryonis',
#  'leading',
#  'under',
#  'western',
#  'stars',
#  'film',
#  'directed',
#  'joseph',
#  'kane',
#  'starring',
#  'victor',
#  'mancha',
#  'victorious',
#  'surface',
#  'area',
#  'interacts',
#  'with',
#  'working',
#  'fluid',
#  'gas',
#  'use',
#  'roman',
#  'cement',
#  'substance',
#  'developed',
#  'james',
#  'parker',
#  '1780s',
#  'being',
#  'patented',
#  'stohlman',
#  '15',
#  '1919',
#  '6',
#  '1998',
#  'pioneer',
#  'leathercraft',
#  'hamishmar',
#  'guard',
#  'daily',
#  'mandatory',
#  'palestine',
#  'abrahamson',
#  'may',
#  '19',
#  '1933',
#  'retired',
#  'general',
#  'goldthwait',
#  'cup',
#  'awarded',
#  'winner',
#  'annual',
#  'triangular',
#  'regatta',
#  'among',
#  'association',
#  'space',
#  'explorers',
#  'organization',
#  'membership',
#  'composed',
#  'people',
#  'jim',
#  'mccrary',
#  '31',
#  'april',
#  '29',
#  'photographer',
#  'effect',
#  'term',
#  'used',
#  'political',
#  'science',
#  'studies',
#  'hungarian',
#  'nyustya',
#  'sobota',
#  'bombing',
#  'memo',
#  'unpublished',
#  'memorandum',
#  'made',
#  'within',
#  'british',
#  'government',
#  'security',
#  'refers',
#  'techniques',
#  'methods',
#  'attempt',
#  'protect',
#  'muharrir',
#  'liberator',
#  'editor',
#  'iraqi',
#  'building',
#  'situated',
#  'zone',
#  'opal',
#  'luna',
#  'saturnyne',
#  'news',
#  'channel',
#  'announced',
#  'paomo',
#  'specialty',
#  'shaanxi',
#  'cuisine',
#  'typical',
#  'food',
#  'eaten',
#  'wolfgang',
#  'nordwig',
#  '27',
#  '1943',
#  'pole',
#  'vaulter',
#  'he',
#  'competed',
#  'akwila',
#  'thompson',
#  'simpasa',
#  '1945',
#  'zambian',
#  'musician',
#  'somewhat',
#  'enigmatic',
#  'aura',
#  'contraction',
#  'surnames',
#  'three',
#  'footballers',
#  'gunnar',
#  'gren',
#  'nordahl',
#  'ala',
#  'kheir',
#  '1985',
#  'nyala',
#  'sudan',
#  'sudanese',
#  'lancelot',
#  'richard',
#  'gibbs',
#  '1934',
#  'west',
#  'indies',
#  'cricketer',
#  'akonnedi',
#  'shrine',
#  'larteh',
#  'eastern',
#  'ghana',
#  'whitcomb',
#  'pod',
#  'positioned',
#  'metakaolin',
#  'anhydrous',
#  'calcined',
#  'clay',
#  'mineral',
#  'kaolinite',
#  'minerals',
#  'rich',
#  'aksel',
#  'february',
#  '1883',
#  '9',
#  'danish',
#  'wood',
#  'akmyrat',
#  'rejepow',
#  'turkmen',
#  'hierarch',
#  'having',
#  'served',
#  'saparmurat',
#  'niyazov',
#  'chief',
#  '2257',
#  'globular',
#  'cluster',
#  'lies',
#  'outskirts',
#  'large',
#  'magellanic',
#  'vidnava',
#  'weidenau',
#  'polish',
#  'widnawa',
#  'olomouc',
#  'burj',
#  'arab',
#  'tower',
#  'arabs',
#  'luxury',
#  'hotel',
#  'gnarrk',
#  'caveman',
#  'bus',
#  'shuttle',
#  'airspace',
#  'portion',
#  'atmosphere',
#  'controlled',
#  'country',
#  'above',
#  'its',
#  'territory',
#  'including',
#  'julius',
#  'nyerere',
#  'agriculture',
#  'jnua',
#  'proposed',
#  'will',
#  'be',
#  'astrup',
#  'rectory',
#  'church',
#  'listed',
#  'tashtamirovich',
#  'noukhayev',
#  '11',
#  '1954',
#  'spelled',
#  'nukhaev',
#  'airports',
#  'serbia',
#  'serbian',
#  'cyrillic',
#  'owns',
#  'hatem',
#  'abdel',
#  'latif',
#  'egyptian',
#  'transport',
#  'cabinet',
#  'leif',
#  'elggren',
#  '1950',
#  'sweden',
#  'lives',
#  'works',
#  'relocation',
#  'teams',
#  'occurs',
#  'when',
#  'owner',
#  'moves',
#  'generally',
#  'chatin',
#  'sarachi',
#  'paskal',
#  '5824',
#  'constellation',
#  'lupus',
#  'almost',
#  'border',
#  'jesus',
#  'interdenominational',
#  'event',
#  'christians',
#  'through',
#  'towns',
#  'revolution',
#  'tripoli',
#  'libya',
#  'lin',
#  'dan',
#  'badminton',
#  'authority',
#  'independent',
#  'entity',
#  'charged',
#  'operation',
#  'oversight',
#  'ulrich',
#  'hans',
#  'walter',
#  'physicist',
#  'engineer',
#  'packing',
#  'involved',
#  'canned',
#  'meat',
#  'industry',
#  'coat',
#  'arms',
#  'leeds',
#  'council',
#  'derives',
#  'seventeenth',
#  'century',
#  'deacon',
#  'akie',
#  'dagogo',
#  'theodore',
#  'fubara',
#  'banker',
#  'businessman',
#  'philanthropist',
#  'melvin',
#  'whinfield',
#  'peerless',
#  'mel',
#  'sheppard',
#  '5',
#  '4',
#  '1942',
#  'catherine',
#  'kate',
#  'private',
#  'catholic',
#  'liberal',
#  'arts',
#  'paul',
#  'hubble',
#  'search',
#  'transition',
#  'comets',
#  'oh',
#  'emissions',
#  'asteroids',
#  'vladimir',
#  'aleksandrovich',
#  'dzhanibekov',
#  'cosmonaut',
#  'french',
#  'composer',
#  'gabriel',
#  'wrote',
#  'many',
#  'genres',
#  'songs',
#  'music',
#  'orchestral',
#  'spicy',
#  'sauce',
#  'often',
#  'contains',
#  'tomatoes',
#  'cilantro',
#  'coriander',
#  'pepper',
#  'onions',
#  'courteen',
#  'later',
#  'called',
#  'assada',
#  'trading',
#  'renacci',
#  '1958',
#  'accountant',
#  'alwasat',
#  'manama',
#  'bahrain',
#  'documentary',
#  'festival',
#  'showcasing',
#  'documentaries',
#  'endowed',
#  'qatar',
#  'world',
#  'nie',
#  'haisheng',
#  'liberation',
#  'hot',
#  'sweet',
#  'chili',
#  'puerto',
#  'rico',
#  'traditionally',
#  'alternative',
#  'privately',
#  'owned',
#  'millions',
#  'cairo',
#  'egypt',
#  'history',
#  'stein',
#  '2051',
#  'gliese',
#  'g',
#  'lhs',
#  'nearby',
#  'binary',
#  'star',
#  'system',
#  'containing',
#  'votice',
#  'wotitz',
#  'central',
#  'toriyama',
#  '1994',
#  'sugar',
#  'crust',
#  'chocolate',
#  'confectionery',
#  'method',
#  'prepare',
#  'liquid',
#  'liqueur',
#  'filled',
#  'chocolates',
#  'aksjeselskap',
#  'norwegian',
#  'usually',
#  'abbreviated',
#  'historically',
#  'oats',
#  'pinhead',
#  'coarse',
#  'oatmeal',
#  'irish',
#  'groats',
#  '2452',
#  'planetary',
#  'southern',
#  'puppis',
#  'assassination',
#  'upon',
#  'leonid',
#  'brezhnev',
#  'deserter',
#  'memphis',
#  'route',
#  'traffic',
#  'control',
#  'center',
#  'zme',
#  'radio',
#  'communications',
#  'suliman',
#  'yari',
#  ...]

# %%
vocab_size = 4096
sequence_length = 10

vectorize_layer = layers.TextVectorization(
    max_tokens=vocab_size,
    output_mode='int',
    output_sequence_length=sequence_length)

# %%
# Construct tf dataset
text = df['Sentence'].tolist()
# text = tf.data.Dataset.from_tensor_slices(text).filter(lambda x: tf.cast(tf.strings.length(x), bool))
print(text[:5])
# Out:
# ['The Cardiff Roller Collective (CRoC) are a roller sports league based in Cardiff, Wales. Founded', '"Go! Pack Go!" is the fight song of the Green Bay Packers, and the first', 'Al-Machriq (English translation: The East) was a journal founded in 1898 by Jesuit and Chaldean', 'Ajman International Airport (Arabic: مطار عجمان الدولي) was an upcoming airport which is currently a', 'Kapla is a construction set for children and adults. The sets consist only of identical']

# %%
# Vecotorisation
vectorize_layer.adapt(text)

vectorize_sequences = vectorize_layer(text)
vectorize_sequences_np = vectorize_sequences.numpy()

for seq in vectorize_sequences[:5]:
   print(seq)
# Out:
# tf.Tensor([  4 224 145 930 901  45   3 145  76 722], shape=(10,), dtype=int64)
# tf.Tensor([194 602 194   2   4 839 464   6   4 192], shape=(10,), dtype=int64)
# tf.Tensor([1041   54  398    4  207    9    3  747  100    5], shape=(10,), dtype=int64)
# tf.Tensor([1066   63   24   12  288  292  301    9    8  383], shape=(10,), dtype=int64)
# tf.Tensor([ 739    2    3  918  491   17  945    7 1084    4], shape=(10,), dtype=int64)

# %%
print(vectorize_layer.get_vocabulary())
# Out:
# ['', '[UNK]', 'is', 'a', 'the', 'in', 'of', 'and', 'an', 'was', 'born', 'by', 'arabic', 'american', 'al', 'to', 'or', 'for', 'from', '–', 'that', 'published', 'fictional', 'as', 'airport', 'newspaper', 'jazeera', 'former', 'university', 'on', 'ngc', 'located', 'german', 'company', 'comic', 'college', 'appearing', 'who', 'which', 'town', 'politician', 'one', 'its', 'it', 'books', 'are', 'also', 'team', 'swedish', 'professional', 'october', 'november', 'march', 'january', 'english', 'district', 'comics', 'character', 'august', 'us', 'uk', 'network', 'known', 'international', 'artist', 'akira', 'air', '20', '13', 'with', 'when', 'western', 'weekly', 'used', 'urdu', 'superhero', 'sports', 'served', 'september', 'russian', 'richard', 'region', 'pronunciation', 'painter', 'nebula', 'name', 'mozzarella', 'media', 'meaning', 'may', 'marvel', 'lit', 'june', 'james', 'including', 'he', 'has', 'government', 'given', 'general', 'founded', 'film', 'december', 'dc', 'daily', 'czech', 'chinese', 'carrozza', 'bus', 'body', 'astrup', 'alwasat', '3', '22', '1898', 'الجزيرة', 'yandev', 'whitcomb', 'undesirable', 'uncommanded', 'type', 'transition', 'traditional', 'tracy', 'toriyama', 'tomb', 'territory', 'term', 'teams', 'taurus', 't', 'surpass', 'supernova', 'students', 'state', 'st', 'shuttle', 'serbian', 'search', 'saudi', 'sauce', 'saint', 'ryō', 'rotation', 'rotating', 'roller', 'remnant', 'relocation', 'rectory', 'public', 'positioned', 'portion', 'pod', 'player', 'pitchup', 'passengers', 'palace', 'owner', 'omer', 'often', 'occurs', 'oats', 'oatmeal', 'noseupwards', 'northern', 'nonprofit', 'mänttävilppula', 'municipality', 'moves', 'mosque', 'monteverde', 'minister', 'memphis', 'maritime', 'major', 'made', 'm1', 'lighthouse', 'light', 'launched', 'language', 'kurdi', 'john', 'japanese', 'japan', 'italian', 'indian', 'hot', 'hebrew', 'gunnar', 'groups', 'group', 'green', 'governmental', 'go', 'globular', 'generally', 'form', 'force', 'football', 'first', 'figure', 'festival', 'february', 'europe', 'egyptian', 'education', 'east', 'designations', 'design', 'danish', 'current', 'crab', 'court', 'country', 'controlled', 'constellation', 'cluster', 'city', 'chatin', 'chamber', 'center', 'catalogue', 'castle', 'cardiff', 'called', 'caldwell', 'businessman', 'building', 'been', 'beacon', 'based', 'attempt', 'atmosphere', 'astronaut', 'association', 'assembly', 'arabia', 'april', 'antishock', 'annual', 'angelo', 'angel', 'allowing', 'aldrin', 'albanian', 'alan', 'aktieselskab', 'akmal', 'akabeko', 'ají', 'airway', 'airspace', 'airline', 'aircraft', 'aerodynamics', 'aerial', 'academic', 'above', '9', '30', '29', '2452', '2012', '1983', '1969', '1964', '1957', '1954', '1952', '1949', '1942', '1939', '1938', '19', '1883', '14', '10', '1', '鳥山', '赤べこ', '艾窩窩', '神道', '梁', '晃', '明', '⅍', '“the', 'مطار', 'مباشر', 'قصر', 'علاء', 'عجمان', 'خير', 'برج', 'الوسط', 'المُحَرِّر', 'الملايين', 'الفضل', 'العرب', 'الزقورة', 'الدولي', 'الجماهير', 'الجزیرہ', 'الثورة', 'التلميذ', 'البيرق', 'البديل', 'اردو', 'أردو', 'תָּמִיד', 'על', 'המשמר', 'אֵשׁ', 'ХожАхмет', 'Таштамирович', 'Србије', 'Ольга', 'Нухаев', 'Криштоп', 'Икрамович', 'Икрамов', 'Джанибеков', 'Владимир', 'Александрович', 'Акмаль', 'Аеродроми', 'Ομέρ', 'Βρυώνης', 'ˈʒɪdloxovɪtsɛ', 'ˈɑkɕəselˌskɛˀp', 'ˈvocɪtsɛ', 'ˈsɑʋonˌlinːɑ', 'ˈsmɪr̝ɪtsɛ', 'Židlochovice', 'àiwōwo', 'zone', 'zme', 'zambian', 'zachary', 'youth', 'yari', 'wrote', 'writer', 'wrigley', 'wotitz', 'worlds', 'works', 'working', 'wood', 'womens', 'wolfgang', 'within', 'winner', 'william', 'will', 'widnawa', 'whinfield', 'whereby', 'west', 'were', 'welsh', 'weidenau', 'walter', 'walker', 'wales', 'vryonis', 'vrioni', 'votice', 'volleyball', 'vladimir', 'village', 'vidnava', 'victorious', 'victor', 'veteran', 'vaulter', 'uzbek', 'usually', 'user', 'use', 'uran', 'upon', 'upcoming', 'unpublished', 'united', 'unicode', 'under', 'ulrich', 'ugandan', 'u214d', 'typically', 'typical', 'turkmen', 'tumaini', 'tripoli', 'triangular', 'transport', 'translation',  ...

# %%
# Generate training data
# Generates skip-gram pairs with negative sampling for a list of sequences
def generate_training_data(sequences, window_size, num_ns, vocab_size, seed):

  targets, contexts, labels = [], [], []

  # Build the sampling table for vocab_size tokens.
  sampling_table = tf.keras.preprocessing.sequence.make_sampling_table(vocab_size)

 
  for sequence in tqdm.tqdm(sequences):

    # Generate positive skip-gram pairs for a sequence (sentence).
    positive_skip_grams, _ = tf.keras.preprocessing.sequence.skipgrams(
          sequence,
          vocabulary_size=vocab_size,
          sampling_table=sampling_table,
          window_size=window_size,
          negative_samples=0)

    # Iterate over each positive skip-gram pair to produce training examples with a positive context word and negative samples.
    for target_word, context_word in positive_skip_grams:
      context_class = tf.expand_dims(
          tf.constant([context_word], dtype="int64"), 1)
      negative_sampling_candidates, _, _ = tf.random.log_uniform_candidate_sampler(
          true_classes=context_class,
          num_true=1,
          num_sampled=num_ns,
          unique=True,
          range_max=vocab_size,
          seed=seed,
          name="negative_sampling")

      # Build context and label vectors (for one target word)
      context = tf.concat([tf.squeeze(context_class,1), negative_sampling_candidates], 0)
      label = tf.constant([1] + [0]*num_ns, dtype="int64")

      # Append each element from the training example to global lists.
      targets.append(target_word)
      contexts.append(context)
      labels.append(label)

  return targets, contexts, labels

# %%
targets, contexts, labels = generate_training_data(
    sequences=vectorize_sequences_np,
    window_size=2,
    num_ns=4,
    vocab_size=vocab_size,
    seed=42)

targets = np.array(targets)
contexts = np.array(contexts)
labels = np.array(labels)

print(targets.shape, contexts.shape, labels.shape)
# Out:
# 100%|██████████| 160/160 [00:00<00:00, 706.09it/s]
# (627,) (627, 5) (627, 5)

# %%
# Configure the dataset for performance
BATCH_SIZE = 1024
BUFFER_SIZE = 10000
dataset = tf.data.Dataset.from_tensor_slices(((targets, contexts), labels))
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)
print(dataset)
# Out:
# <_BatchDataset element_spec=((TensorSpec(shape=(1024,), dtype=tf.int64, name=None), TensorSpec(shape=(1024, 5), dtype=tf.int64, name=None)), TensorSpec(shape=(1024, 5), dtype=tf.int64, name=None))>

# %%
# to improve performance 
AUTOTUNE = tf.data.AUTOTUNE
dataset = dataset.cache().prefetch(buffer_size=AUTOTUNE)
print(dataset)
# Out:
# <_PrefetchDataset element_spec=((TensorSpec(shape=(1024,), dtype=tf.int64, name=None), TensorSpec(shape=(1024, 5), dtype=tf.int64, name=None)), TensorSpec(shape=(1024, 5), dtype=tf.int64, name=None))>

# %%
# Model trainig
embedding_dim = 128
class Word2Vec(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim):
        super(Word2Vec, self).__init__()
        self.target_embedding = layers.Embedding(vocab_size, 
                                                 embedding_dim, 
                                                 input_length=1, 
                                                 name='w2v_embedding')
        self.context_embedding = layers.Embedding(vocab_size, 
                                                 embedding_dim)
        
    def call(self, pair):
        target, context = pair

        # context: batch, context
        if len(target.shape) == 2:
            target = tf.squeeze(target, axis=1)

        # target: (batch,)
        word_emb = self.target_embedding(target)
        # word_emb: (batch, embed)
        context_emb = self.context_embedding(context)
        # context_emb: (batch, context, embed)
        dots = tf.einsum('be,bce->bc', word_emb, context_emb)
        return dots

# %%
# loss function and model compile
def custom_loss(x_logit, y_true):
      return tf.nn.sigmoid_cross_entropy_with_logits(logits=x_logit, labels=y_true)

# %%
embedding_dim = 128
word2vec = Word2Vec(vocab_size, embedding_dim)
word2vec.compile(optimizer='adam',
                 loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
                 metrics=['accuracy'])

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir="logs")

# %%
word2vec.fit(dataset, epochs=20, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 2024-07-03 13:52:27.027376: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 word2vec.fit(dataset, epochs=20, callbacks=[tensorboard_callback])
#
# File ~/Projects/Learning/venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/Projects/Learning/venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:325, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     322             break
#     324 # Override with model metrics instead of last step logs if needed.
# --> 325 epoch_logs = dict(self._get_metrics_result_or_logs(logs))
#     327 # Run validation.
#     328 if validation_data is not None and self._should_eval(
#     329     epoch, validation_freq
#     330 ):
#     331     # Create EpochIterator for evaluation and cache it.
#
# TypeError: 'NoneType' object is not iterable
